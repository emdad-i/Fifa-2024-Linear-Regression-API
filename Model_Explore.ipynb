# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv('data/male_players.csv',encoding='utf-8')
# Out:
# /var/folders/75/x8nkyv053bg9h7f_hhzr_n8h0000gn/T/ipykernel_50747/4090037889.py:1: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data/male_players.csv',encoding='utf-8')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180021 entries, 0 to 180020
# Columns: 109 entries, player_id to gk
# dtypes: float64(20), int64(43), object(46)
# memory usage: 149.7+ MB

# %%
data.describe()
# Out:
#            player_id   fifa_version  fifa_update        overall  \
# count  180021.000000  180021.000000     180021.0  180021.000000
# mean   217326.670294      19.621450          2.0      65.712711
# std     35215.749284       2.838621          0.0       7.018104
# min         2.000000      15.000000          2.0      40.000000
# 25%    200759.000000      17.000000          2.0      61.000000
# 50%    222734.000000      20.000000          2.0      66.000000
# 75%    239858.000000      22.000000          2.0      70.000000
# max    278145.000000      24.000000          2.0      94.000000
#
#            potential     value_eur      wage_eur            age  \
# count  180021.000000  1.778680e+05  178173.00000  180021.000000
# mean       70.779581  2.379142e+06   10638.01081      25.138689
# std         6.255569  6.184358e+06   21637.41400       4.679389
# min        40.000000  1.000000e+03     500.00000      16.000000
# 25%        66.000000  3.250000e+05    2000.00000      21.000000
# ...

# %%
data.columns.tolist()
# Out:
# ['player_id',
#  'player_url',
#  'fifa_version',
#  'fifa_update',
#  'update_as_of',
#  'short_name',
#  'long_name',
#  'player_positions',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'club_team_id',
#  'club_name',
#  'league_id',
#  'league_name',
#  'league_level',
#  'club_position',
#  'club_jersey_number',
#  'club_loaned_from',
#  'club_joined_date',
#  'club_contract_valid_until_year',
#  'nationality_id',
#  'nationality_name',
#  'nation_team_id',
#  'nation_position',
#  'nation_jersey_number',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'international_reputation',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'player_traits',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
# ...

# %%
sns.displot(data['wage_eur'])
